# %% [markdown]
# ### Render
#
# https://dashboard.render.com/
#
# Service ID: $SRV_ID0
#
# URL: https://perturb-agent.onrender.com

# %% [markdown]
# ### Project
#
# #### Folders
#
# - Name: perturb_agent
# - Language: Python 3
# - Branch: main
# - Region: Veriginia (US East)
# - Root dirctory: .
#
# - Start command - last line Dockerfile
#   - streamlit run app.py --server.address 0.0.0.0 --server.port $PORT
#
#
# Render:
# - ~/project/src
# - ~/project/src/storage/data
#
# Environment Variables:
#
# - GDRIVE_FOLDER_ID -- Ok
# - GOOGLE_SERVICE_ACCOUNT_JSON - Ok
# - PYTHON_VERSION=3.11.4
#
# Local:
# - flalix / perturb_agent

# %% [markdown]
# ### Runtime
#
# 1. Service ID: srv-d7b9lbogjchc7393jvl
# 2. Website: https://perturb-agent.onrender.com

# %% [markdown]
# ### ssh publick key
#
#
# cd ~/.ssh
# ssh-keygen
# enter, enter
# ls -ls
#
#
# ssh-keygen -lf ~/.ssh/id_ed25519.pub
# cat ~/.ssh/id_ed25519.pub
# ssh-add -l

# %% [markdown]
# ### Refresh the hos tkey:
#
# ssh-keygen -R ssh.virginia.render.com
#
# ssh -i ~/.ssh/id_ed25519 -o IdentitiesOnly=yes -o UpdateHostKeys=no $SRV_ID@ssh.virginia.render.com

# %% [markdown]
# ### rsync
#
# https://perturb-agent.onrender.com
#
#
# cd ~/uv/perturb_agent/data/GTEx/
#
# SRV_ID=srv-d7b9lbogjchc7393jvl0
#
# rsync -avzP -e "ssh -i ~/.ssh/id_ed25519 -o IdentitiesOnly=yes" *.tsv \
# $SRV_ID@ssh.virginia.render.com:/opt/render/project/src/storage/data/GTEx/
#
# > **split huge files in chunks**
#
# split -b 10M GTEx_Analysis_2025-08-22_v11_RNASeQCv2.4.3_gene_reads.gct.gz part_
#
# rsync -avzP -e "ssh -i ~/.ssh/id_ed25519 -o IdentitiesOnly=yes" part_* \
# $SRV_ID@ssh.virginia.render.com:/opt/render/project/src/storage/data/GTEx/
#
# > **better1**
#
# #==============================
# rsync -avP -e "ssh -i ~/.ssh/id_ed25519 -o --ignore-existing --checksum IdentitiesOnly=yes -o UpdateHostKeys=no" --include="*.tsv" --exclude="*" ./ \
# $SRV_ID@ssh.virginia.render.com:/opt/render/project/src/storage/data/GTEx/
# #==============================
#
#
# rsync -avzP -e "ssh -i ~/.ssh/id_ed25519 -o IdentitiesOnly=yes -o UpdateHostKeys=no" part_* \
# $SRV_ID@ssh.virginia.render.com:/opt/render/project/src/storage/data/GTEx/
#
# > **better2**
#
# rsync -avP --partial --append-verify \
# -e "ssh -i ~/.ssh/id_ed25519 -o IdentitiesOnly=yes -o UpdateHostKeys=no -o ServerAliveInterval=30 -o ServerAliveCountMax=10" \
# *.gct.gz $SRV_ID@ssh.virginia.render.com:/opt/render/project/src/storage/data/GTEx/
#
#
# > **one by one**
#
# for f in part_*; do
#   echo "Uploading $f"
#   rsync -avP --bwlimit=1000 \
#   -e "ssh -T -i ~/.ssh/id_ed25519 -o IdentitiesOnly=yes -o UpdateHostKeys=no -o Compression=no" \
#   "$f" \
#   $SRV_ID@ssh.virginia.render.com:/opt/render/project/src/storage/data/GTEx/
# done
#
#
# > **merge in the server**
#
# cat part_* > GTEx_Analysis_2025-08-22_v11_RNASeQCv2.4.3_gene_reads.gct.gz
#
#
#
# # checking files
# ssh -i ~/.ssh/id_ed25519 -o IdentitiesOnly=yes -o UpdateHostKeys=no $SRV_ID@ssh.virginia.render.com \
# "ls -lh /opt/render/project/src/storage/data/GTEx/"
#
# #### SSH command:
#
# SRV_ID=srv-d7b9lbogjchc7393jvl
#
# ssh srv-d7b9lbogjchc7393jvl0@ssh.virginia.render.com
