# %% [markdown]
# ## Literature

# %% [markdown]
# ### Phenotype, disease, genes and drugs
#
# 1. Gene–phenotype associations:
#     * [dbGaP](https://dbgap.ncbi.nlm.nih.gov/home/)
#     * [PhenoScanner](https://github.com/phenoscanner/phenoscanner)
#     * [PheGenI](https://www.ncbi.nlm.nih.gov/gap/phegeni)
# 2. Gene–disease associations:
#     * [MalaCards](https://www.malacards.org/)
#     * [DisGeNET](https://disgenet.com/)
# 3. Drug associations:
#     * [LINCS](https://clue.io/lincs) (perturbation signatures)
#     * [Allosteric Database](https://mdl.shsmu.edu.cn/ASD/)
#     * [Drug-Gene Interaction Database (DGIdb)](https://dgidb.org/about/overview/introduction)
#     * [DrugBank](https://go.drugbank.com/)
#     * [ChEMBL](https://www.ebi.ac.uk/chembl/)
# 4. Mechanism of action (MOA):
#     * inferred from LINCS perturbation profiles
#
# 5. Mutation:
#     * [Allosteric Mutation Analysis and Polymorphism of Signaling database](https://allomaps.bii.a-star.edu.sg/)
#     * [OMIM](https://www.omim.org/)
#
# 6. ClinVar (NIH)
#      * [ClinVar](https://www.ncbi.nlm.nih.gov/clinvar/)

# %% [markdown]
# ### LLM and AI
#
# 1. Foundation Models
#      * [TAHOE](https://www.tahoebio.ai/) perturbed datasets
#          * 120M+ cells and 225,000 perturbation interactions
#      * [Tahoe Bio LLMs](https://huggingface.co/tahoebio) a gigascale single cell perturbational atlas (May 2025)
# 2. Practical categorization - bioinformatics / omics
#      * BioGPT
#      * PubMedBERT
#      * MEDITRON (🔥)
#      * GPT-4-class (with RAG 🔥)
#      * [Biochatter](https://biochatter.org/latest/) (🔥)
# 3. Top Models
#      * GPT-4 / GPT-4-class models
#      * Gemini (Google)
#      * Claude (Anthropic)
# 4. Health and Bio:
#      * BioGPT (Microsoft)
#      * BioMedLM
#      * PubMedGPT
#      * PubMedBERT
#      * MEDITRON (7B / 70B)
#      * Me-LLaMA (medical LLaMA variants)
#      * Med-PaLM
#      * Med-PaLM 2
#      * MedLM (productized version)
#      * ClinicalCamel
#      * MedAlpaca
#      * GatorTron (earlier, not generative)
#      * SM70 (medical device LLM)
# 5. Hybrid / instruction-tuned medical LLMs
#      * Flan-PaLM (medical tuning)
#      * LLaMA + medical instruction tuning
#      * Alpaca-Med / MedAlpaca
# 6. Benchmarks / evaluation ecosystems
#      * MedQA (USMLE-style questions)
#      * PubMedQA
#      * MedMCQA
#      * MultiMedQA
