# %%
import shutil
import subprocess

# %%
print("Rscript in PATH:", shutil.which("Rscript"))

subprocess.run(["conda", "run", "-n", "renv", "which", "Rscript"], check=True)
subprocess.run(["conda", "run", "-n", "renv", "Rscript", "--version"], check=True)
# Out:
# Rscript in PATH: None
# /home/flavio/miniforge3/envs/renv/bin/Rscript
# Rscript (R) version 4.5.3 (2026-03-11)
# CompletedProcess(args=['conda', 'run', '-n', 'renv', 'Rscript', '--version'], returncode=0)
