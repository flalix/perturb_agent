# %% [markdown]
# ### dash-cytoscape

# %%
import sys
from pathlib import Path

ROOT0 = Path("/home/flavio/uv/perturb_agent/")
ROOT_SRC = ROOT0 / "src"

if str(ROOT_SRC) not in sys.path:
    sys.path.append(str(ROOT_SRC))

print("ROOT0:", ROOT0)
print("ROOT_SRC added:", ROOT_SRC)

from libs.Basic import *
from libs.dashcyto_lib import DASH_CYTO
# Out:
# ROOT0: /home/flavio/uv/perturb_agent
# ROOT_SRC added: /home/flavio/uv/perturb_agent/src

# %%
dcy = DASH_CYTO(ROOT0=ROOT0)

# %%
owl_file = "R-HSA-165159_level3.owl"
owl_file = "R-HSA-114608_level3.owl"

pathway = 'Platelet degranulation'
pathway_id = "R-HSA-114608"

rdf = dcy.read_owl(pathway_id, pathway)

# %% [markdown]
# ```Python
# G.nodes[gene_id]["log2FC"] = log2fc
# G.nodes[gene_id]["FDR"] = fdr
# G.nodes[gene_id]["mutated"] = True
# ```

# %% [markdown]
# ### OWL to Graph

# %%
saved_positions = dcy.load_positions(pathway_id)
# Out:
# Data loaded from /home/flavio/uv/perturb_agent/owl/positions_R-HSA-114608.json

# %%
i=0
for key, posi in saved_positions.items():
    print(key, posi)
    i+=1
    if i==3: break
# Out:
# Protein120 {'x': 1267.0432252641417, 'y': 15}
# Protein271 {'x': 284.5513360155917, 'y': 209.13100742353586}
# Protein30 {'x': 61.89502119452777, 'y': 288.8275793727621}

# %% [markdown]
# ### Dash

# %%
height = "1100px"
width = "100%"
marginTop="20px"

dcy.run_app(height=height, width=width, marginTop=marginTop)
# Out:
# Data loaded from /home/flavio/uv/perturb_agent/owl/positions_R-HSA-114608.json
# Open in browser: http://localhost:8050
# Dash app running on http://127.0.0.1:8050/
# [2026-05-04 15:17:55,505] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/flavio/uv/perturb_agent/.venv/lib/python3.11/site-packages/flask/app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/flavio/uv/perturb_agent/.venv/lib/python3.11/site-packages/flask/app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/flavio/uv/perturb_agent/.venv/lib/python3.11/site-packages/flask/app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/flavio/uv/perturb_agent/.venv/lib/python3.11/site-packages/flask/app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/flavio/uv/perturb_agent/.venv/lib/python3.11/site-packages/dash/_get_app.py", line 17, in wrap
#     return ctx.run(func, self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/flavio/uv/perturb_agent/.venv/lib/python3.11/site-packages/dash/dash.py", line 1601, in dispatch
#     response_data = ctx.run(partial_func)
#                     ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/flavio/uv/perturb_agent/.venv/lib/python3.11/site-packages/dash/_callback.py", line 720, in add_context
#     raise err
#   File "/home/flavio/uv/perturb_agent/.venv/lib/python3.11/site-packages/dash/_callback.py", line 711, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)  # type: ignore[reportArgumentType]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/flavio/uv/perturb_agent/.venv/lib/python3.11/site-packages/dash/_callback.py", line 58, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#            ^^^^^^^^^^^^^^^^^^^^^
# TypeError: DASH_CYTO.create_cytoscape_app.<locals>.save_and_notify() missing 1 required positional argument: 'elements'
