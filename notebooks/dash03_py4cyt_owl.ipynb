# %% [markdown]
# ### dash-cytoscape

# %%
import sys
from pathlib import Path

ROOT0 = Path("/home/flavio/uv/perturb_agent/")
ROOT_SRC = ROOT0 / "src"

if str(ROOT_SRC) not in sys.path:
    sys.path.append(str(ROOT_SRC))

print("ROOT0:", ROOT0)
print("ROOT_SRC added:", ROOT_SRC)

from libs.Basic import *
from libs.dashcyto_lib import DASH_CYTO
# Out:
# ROOT0: /home/flavio/uv/perturb_agent
# ROOT_SRC added: /home/flavio/uv/perturb_agent/src

# %%
dcy = DASH_CYTO(ROOT0=ROOT0)
# Out:
# >>> df hugo Index(['ensembl_id', 'symbol', 'name', 'uniprot_id', 'refseq_summary',
#        'ensembl_id_base'],
#       dtype='object')
# Loaded gene annotation table: /home/flavio/uv/perturb_agent/data/ncbi/hugo_gene_table_refseq_uniprot.tsv
# Rows: 39,740
# Symbols: 39,537
# Ensembl IDs: 39,740

# %% [markdown]
# ### fname_gene_alias = "hugo_gene_alias_table.tsv"

# %%
force=False
verbose=False

dfh = pdreadcsv(dcy.fname_hugo, dcy.root_ncbi, verbose=verbose)
dfh.columns
# Out:
# Index(['ensembl_id', 'symbol', 'name', 'uniprot_id', 'ncbi_gene_id',
#        'synonyms', 'refseq_summary'],
#       dtype='object')

# %%
owl_file = "R-HSA-165159_level3.owl"
owl_file = "R-HSA-114608_level3.owl"

pathway = 'Platelet degranulation'
pathway_id = "R-HSA-114608"

rdf = dcy.read_owl(pathway_id, pathway)

# %% [markdown]
# ```Python
# G.nodes[gene_id]["log2FC"] = log2fc
# G.nodes[gene_id]["FDR"] = fdr
# G.nodes[gene_id]["mutated"] = True
# ```

# %% [markdown]
# ### OWL to Graph

# %%
saved_positions = dcy.load_positions(pathway_id)
# Out:
# Data loaded from /home/flavio/uv/perturb_agent/data/owl/positions_R-HSA-114608.json

# %%
i=0
for key, posi in saved_positions.items():
    print(key, posi)
    i+=1
    if i==3: break
# Out:
# Protein46 {'x': 1089.2281544150715, 'y': 170.56669566144214}
# PhysicalEntity6 {'x': 188.53386155690094, 'y': 447.28101611825684}
# PhysicalEntity4 {'x': 46.6583784124059, 'y': 227.10534621909645}

# %% [markdown]
# ### Synonyms table

# %%
# df = pdreadcsv(dcy.fname_hugo, dcy.root_ncbi)
# df.head(2)

# %%
force=False
verbose=True

# dfsyn = dcy.build_gene_alias_table(force=force, verbose=verbose)
# dfsyn.head(3)

# %% [markdown]
# ### Dash

# %%
height = "95%"
width = "100%"
marginTop="20px"

dcy.run_app(height=height, width=width, marginTop=marginTop)
# Out:
# Data loaded from /home/flavio/uv/perturb_agent/data/owl/positions_R-HSA-114608.json
# Open in browser: http://localhost:8050
# Dash app running on http://127.0.0.1:8050/
# No gene annotation match for label: ABCC4 accumulation of dense granule contents
# ANNOT: {'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'uniprot_id': 'NA', 'refseq_summary': 'NA', 'synonyms': 'NA', 'matches': [], 'n_matches': 0}
# matches: []
# n_matches: 0
# >>> info_data {'id': 'BiochemicalReaction1', 'label': 'ABCC4 accumulation of dense granule contents', 'biopax_type': 'BiochemicalReaction', 'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'gene_type': 'NA', 'uniprot_id': 'NA', 'synonyms': 'NA', 'refseq_summary': 'NA', 'lfc': 'NA', 'fdr': 'NA', 'matches': [], 'n_matches': 0}
# No gene annotation match for label: Catalysis1
# ANNOT: {'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'uniprot_id': 'NA', 'refseq_summary': 'NA', 'synonyms': 'NA', 'matches': [], 'n_matches': 0}
# matches: []
# n_matches: 0
# >>> info_data {'id': 'Catalysis1', 'label': 'Catalysis1', 'biopax_type': 'Catalysis', 'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'gene_type': 'NA', 'uniprot_id': 'NA', 'synonyms': 'NA', 'refseq_summary': 'NA', 'lfc': 'NA', 'fdr': 'NA', 'matches': [], 'n_matches': 0}
# ANNOT: {'alias': 'ABCC4', 'symbol': 'ABCC4', 'ensembl_id': 'ENSG00000125257', 'name': 'ATP binding cassette subfamily C member 4', 'uniprot_id': 'O15439', 'refseq_summary': 'The protein encoded by this gene is a member of the superfamily of ATP-binding cassette (ABC) transporters. ABC proteins transport various molecules across extra- and intra-cellular membranes. ABC genes are divided into seven distinct subfamilies (ABC1, MDR/TAP, MRP, ALD, OABP, GCN20, White). This protein is a member of the MRP subfamily which is involved in multi-drug resistance. This family member plays a role in cellular detoxification as a pump for its substrate, organic anions. It may also function in prostaglandin-mediated cAMP signaling in ciliogenesis. Alternative splicing of this gene results in multiple transcript variants. [provided by RefSeq, Sep 2014]', 'matches': [{'alias': 'ABCC4', 'symbol': 'ABCC4', 'ensembl_id': 'ENSG00000125257', 'name': 'ATP binding cassette subfamily C member 4', 'uniprot_id': 'O15439', 'refseq_summary': 'The protein encoded by this gene is a member of the superfamily of ATP-binding cassette (ABC) transporters. ABC proteins transport various molecules across extra- and intra-cellular membranes. ABC genes are divided into seven distinct subfamilies (ABC1, MDR/TAP, MRP, ALD, OABP, GCN20, White). This protein is a member of the MRP subfamily which is involved in multi-drug resistance. This family member plays a role in cellular detoxification as a pump for its substrate, organic anions. It may also function in prostaglandin-mediated cAMP signaling in ciliogenesis. Alternative splicing of this gene results in multiple transcript variants. [provided by RefSeq, Sep 2014]'}], 'n_matches': 1}
# matches: [{'alias': 'ABCC4', 'symbol': 'ABCC4', 'ensembl_id': 'ENSG00000125257', 'name': 'ATP binding cassette subfamily C member 4', 'uniprot_id': 'O15439', 'refseq_summary': 'The protein encoded by this gene is a member of the superfamily of ATP-binding cassette (ABC) transporters. ABC proteins transport various molecules across extra- and intra-cellular membranes. ABC genes are divided into seven distinct subfamilies (ABC1, MDR/TAP, MRP, ALD, OABP, GCN20, White). This protein is a member of the MRP subfamily which is involved in multi-drug resistance. This family member plays a role in cellular detoxification as a pump for its substrate, organic anions. It may also function in prostaglandin-mediated cAMP signaling in ciliogenesis. Alternative splicing of this gene results in multiple transcript variants. [provided by RefSeq, Sep 2014]'}]
# n_matches: 1
# >>> info_data {'id': 'Protein1', 'label': 'ABCC4', 'biopax_type': 'Protein', 'ensembl_id': 'ENSG00000125257', 'symbol': 'ABCC4', 'name': 'ATP binding cassette subfamily C member 4', 'gene_type': 'NA', 'uniprot_id': 'O15439', 'synonyms': 'ABCC4; MOAT-B; MOATB; MRP4', 'refseq_summary': 'The protein encoded by this gene is a member of the superfamily of ATP-binding cassette (ABC) transporters. ABC proteins transport various molecules across extra- and intra-cellular membranes. ABC genes are divided into seven distinct subfamilies (ABC1, MDR/TAP, MRP, ALD, OABP, GCN20, White). This protein is a member of the MRP subfamily which is involved in multi-drug resistance. This family member plays a role in cellular detoxification as a pump for its substrate, organic anions. It may also function in prostaglandin-mediated cAMP signaling in ciliogenesis. Alternative splicing of this gene results in multiple transcript variants. [provided by RefSeq, Sep 2014]', 'lfc': 'NA', 'fdr': 'NA', 'matches': [{'alias': 'ABCC4', 'symbol': 'ABCC4', 'ensembl_id': 'ENSG00000125257', 'name': 'ATP binding cassette subfamily C member 4', 'uniprot_id': 'O15439', 'refseq_summary': 'The protein encoded by this gene is a member of the superfamily of ATP-binding cassette (ABC) transporters. ABC proteins transport various molecules across extra- and intra-cellular membranes. ABC genes are divided into seven distinct subfamilies (ABC1, MDR/TAP, MRP, ALD, OABP, GCN20, White). This protein is a member of the MRP subfamily which is involved in multi-drug resistance. This family member plays a role in cellular detoxification as a pump for its substrate, organic anions. It may also function in prostaglandin-mediated cAMP signaling in ciliogenesis. Alternative splicing of this gene results in multiple transcript variants. [provided by RefSeq, Sep 2014]'}], 'n_matches': 1}
# >>> n_matches 1
# ANNOT: {'alias': 'FGG', 'symbol': 'FGG', 'ensembl_id': 'ENSG00000171557', 'name': 'fibrinogen gamma chain', 'uniprot_id': 'P02679', 'refseq_summary': 'The protein encoded by this gene is the gamma component of fibrinogen, a blood-borne glycoprotein comprised of three pairs of nonidentical polypeptide chains. Following vascular injury, fibrinogen is cleaved by thrombin to form fibrin which is the most abundant component of blood clots. In addition, various cleavage products of fibrinogen and fibrin regulate cell adhesion and spreading, display vasoconstrictor and chemotactic activities, and are mitogens for several cell types. Mutations in this gene lead to several disorders, including dysfibrinogenemia, hypofibrinogenemia and thrombophilia. Alternative splicing results in transcript variants encoding different isoforms. [provided by RefSeq, Aug 2015]', 'matches': [{'alias': 'FGG', 'symbol': 'FGG', 'ensembl_id': 'ENSG00000171557', 'name': 'fibrinogen gamma chain', 'uniprot_id': 'P02679', 'refseq_summary': 'The protein encoded by this gene is the gamma component of fibrinogen, a blood-borne glycoprotein comprised of three pairs of nonidentical polypeptide chains. Following vascular injury, fibrinogen is cleaved by thrombin to form fibrin which is the most abundant component of blood clots. In addition, various cleavage products of fibrinogen and fibrin regulate cell adhesion and spreading, display vasoconstrictor and chemotactic activities, and are mitogens for several cell types. Mutations in this gene lead to several disorders, including dysfibrinogenemia, hypofibrinogenemia and thrombophilia. Alternative splicing results in transcript variants encoding different isoforms. [provided by RefSeq, Aug 2015]'}], 'n_matches': 1}
# matches: [{'alias': 'FGG', 'symbol': 'FGG', 'ensembl_id': 'ENSG00000171557', 'name': 'fibrinogen gamma chain', 'uniprot_id': 'P02679', 'refseq_summary': 'The protein encoded by this gene is the gamma component of fibrinogen, a blood-borne glycoprotein comprised of three pairs of nonidentical polypeptide chains. Following vascular injury, fibrinogen is cleaved by thrombin to form fibrin which is the most abundant component of blood clots. In addition, various cleavage products of fibrinogen and fibrin regulate cell adhesion and spreading, display vasoconstrictor and chemotactic activities, and are mitogens for several cell types. Mutations in this gene lead to several disorders, including dysfibrinogenemia, hypofibrinogenemia and thrombophilia. Alternative splicing results in transcript variants encoding different isoforms. [provided by RefSeq, Aug 2015]'}]
# n_matches: 1
# >>> info_data {'id': 'Protein122', 'label': 'FGG', 'biopax_type': 'Protein', 'ensembl_id': 'ENSG00000171557', 'symbol': 'FGG', 'name': 'fibrinogen gamma chain', 'gene_type': 'NA', 'uniprot_id': 'P02679', 'synonyms': 'FGG', 'refseq_summary': 'The protein encoded by this gene is the gamma component of fibrinogen, a blood-borne glycoprotein comprised of three pairs of nonidentical polypeptide chains. Following vascular injury, fibrinogen is cleaved by thrombin to form fibrin which is the most abundant component of blood clots. In addition, various cleavage products of fibrinogen and fibrin regulate cell adhesion and spreading, display vasoconstrictor and chemotactic activities, and are mitogens for several cell types. Mutations in this gene lead to several disorders, including dysfibrinogenemia, hypofibrinogenemia and thrombophilia. Alternative splicing results in transcript variants encoding different isoforms. [provided by RefSeq, Aug 2015]', 'lfc': 'NA', 'fdr': 'NA', 'matches': [{'alias': 'FGG', 'symbol': 'FGG', 'ensembl_id': 'ENSG00000171557', 'name': 'fibrinogen gamma chain', 'uniprot_id': 'P02679', 'refseq_summary': 'The protein encoded by this gene is the gamma component of fibrinogen, a blood-borne glycoprotein comprised of three pairs of nonidentical polypeptide chains. Following vascular injury, fibrinogen is cleaved by thrombin to form fibrin which is the most abundant component of blood clots. In addition, various cleavage products of fibrinogen and fibrin regulate cell adhesion and spreading, display vasoconstrictor and chemotactic activities, and are mitogens for several cell types. Mutations in this gene lead to several disorders, including dysfibrinogenemia, hypofibrinogenemia and thrombophilia. Alternative splicing results in transcript variants encoding different isoforms. [provided by RefSeq, Aug 2015]'}], 'n_matches': 1}
# >>> n_matches 1
# No gene annotation match for label: FGB(31-491)
# ANNOT: {'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'uniprot_id': 'NA', 'refseq_summary': 'NA', 'synonyms': 'NA', 'matches': [], 'n_matches': 0}
# matches: []
# n_matches: 0
# >>> info_data {'id': 'Protein46', 'label': 'FGB(31-491)', 'biopax_type': 'Protein', 'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'gene_type': 'NA', 'uniprot_id': 'NA', 'synonyms': 'NA', 'refseq_summary': 'NA', 'lfc': 'NA', 'fdr': 'NA', 'matches': [], 'n_matches': 0}
# No gene annotation match for label: Exocytosis of platelet dense granule content
# ANNOT: {'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'uniprot_id': 'NA', 'refseq_summary': 'NA', 'synonyms': 'NA', 'matches': [], 'n_matches': 0}
# matches: []
# n_matches: 0
# >>> info_data {'id': 'BiochemicalReaction2', 'label': 'Exocytosis of platelet dense granule content', 'biopax_type': 'BiochemicalReaction', 'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'gene_type': 'NA', 'uniprot_id': 'NA', 'synonyms': 'NA', 'refseq_summary': 'NA', 'lfc': 'NA', 'fdr': 'NA', 'matches': [], 'n_matches': 0}
# No gene annotation match for label: Integrin alpha2bbeta3
# ANNOT: {'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'uniprot_id': 'NA', 'refseq_summary': 'NA', 'synonyms': 'NA', 'matches': [], 'n_matches': 0}
# matches: []
# n_matches: 0
# >>> info_data {'id': 'Complex16', 'label': 'Integrin alpha2bbeta3', 'biopax_type': 'Complex', 'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'gene_type': 'NA', 'uniprot_id': 'NA', 'synonyms': 'NA', 'refseq_summary': 'NA', 'lfc': 'NA', 'fdr': 'NA', 'matches': [], 'n_matches': 0}
# No gene annotation match for label: PDGF AB heterodimer
# ANNOT: {'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'uniprot_id': 'NA', 'refseq_summary': 'NA', 'synonyms': 'NA', 'matches': [], 'n_matches': 0}
# matches: []
# n_matches: 0
# >>> info_data {'id': 'Complex12', 'label': 'PDGF AB heterodimer', 'biopax_type': 'Complex', 'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'gene_type': 'NA', 'uniprot_id': 'NA', 'synonyms': 'NA', 'refseq_summary': 'NA', 'lfc': 'NA', 'fdr': 'NA', 'matches': [], 'n_matches': 0}
# ANNOT: {'alias': 'c-sis', 'symbol': 'PDGFB', 'ensembl_id': 'ENSG00000100311', 'name': 'platelet derived growth factor subunit B', 'uniprot_id': 'P01127', 'refseq_summary': 'This gene encodes a member of the protein family comprised of both platelet-derived growth factors (PDGF) and vascular endothelial growth factors (VEGF). The encoded preproprotein is proteolytically processed to generate platelet-derived growth factor subunit B, which can homodimerize, or alternatively, heterodimerize with the related platelet-derived growth factor subunit A. These proteins bind and activate PDGF receptor tyrosine kinases, which play a role in a wide range of developmental processes. Mutations in this gene are associated with meningioma. Reciprocal translocations between chromosomes 22 and 17, at sites where this gene and that for collagen type 1, alpha 1 are located, are associated with dermatofibrosarcoma protuberans, a rare skin tumor. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Oct 2015]', 'matches': [{'alias': 'c-sis', 'symbol': 'PDGFB', 'ensembl_id': 'ENSG00000100311', 'name': 'platelet derived growth factor subunit B', 'uniprot_id': 'P01127', 'refseq_summary': 'This gene encodes a member of the protein family comprised of both platelet-derived growth factors (PDGF) and vascular endothelial growth factors (VEGF). The encoded preproprotein is proteolytically processed to generate platelet-derived growth factor subunit B, which can homodimerize, or alternatively, heterodimerize with the related platelet-derived growth factor subunit A. These proteins bind and activate PDGF receptor tyrosine kinases, which play a role in a wide range of developmental processes. Mutations in this gene are associated with meningioma. Reciprocal translocations between chromosomes 22 and 17, at sites where this gene and that for collagen type 1, alpha 1 are located, are associated with dermatofibrosarcoma protuberans, a rare skin tumor. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Oct 2015]'}], 'n_matches': 1}
# matches: [{'alias': 'c-sis', 'symbol': 'PDGFB', 'ensembl_id': 'ENSG00000100311', 'name': 'platelet derived growth factor subunit B', 'uniprot_id': 'P01127', 'refseq_summary': 'This gene encodes a member of the protein family comprised of both platelet-derived growth factors (PDGF) and vascular endothelial growth factors (VEGF). The encoded preproprotein is proteolytically processed to generate platelet-derived growth factor subunit B, which can homodimerize, or alternatively, heterodimerize with the related platelet-derived growth factor subunit A. These proteins bind and activate PDGF receptor tyrosine kinases, which play a role in a wide range of developmental processes. Mutations in this gene are associated with meningioma. Reciprocal translocations between chromosomes 22 and 17, at sites where this gene and that for collagen type 1, alpha 1 are located, are associated with dermatofibrosarcoma protuberans, a rare skin tumor. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Oct 2015]'}]
# n_matches: 1
# >>> info_data {'id': 'Protein71', 'label': 'c-sis', 'biopax_type': 'Protein', 'ensembl_id': 'ENSG00000100311', 'symbol': 'PDGFB', 'name': 'platelet derived growth factor subunit B', 'gene_type': 'NA', 'uniprot_id': 'P01127', 'synonyms': 'IBGC5; PDGF-2; PDGF2; PDGFB; SIS; SSV; c-sis', 'refseq_summary': 'This gene encodes a member of the protein family comprised of both platelet-derived growth factors (PDGF) and vascular endothelial growth factors (VEGF). The encoded preproprotein is proteolytically processed to generate platelet-derived growth factor subunit B, which can homodimerize, or alternatively, heterodimerize with the related platelet-derived growth factor subunit A. These proteins bind and activate PDGF receptor tyrosine kinases, which play a role in a wide range of developmental processes. Mutations in this gene are associated with meningioma. Reciprocal translocations between chromosomes 22 and 17, at sites where this gene and that for collagen type 1, alpha 1 are located, are associated with dermatofibrosarcoma protuberans, a rare skin tumor. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Oct 2015]', 'lfc': 'NA', 'fdr': 'NA', 'matches': [{'alias': 'c-sis', 'symbol': 'PDGFB', 'ensembl_id': 'ENSG00000100311', 'name': 'platelet derived growth factor subunit B', 'uniprot_id': 'P01127', 'refseq_summary': 'This gene encodes a member of the protein family comprised of both platelet-derived growth factors (PDGF) and vascular endothelial growth factors (VEGF). The encoded preproprotein is proteolytically processed to generate platelet-derived growth factor subunit B, which can homodimerize, or alternatively, heterodimerize with the related platelet-derived growth factor subunit A. These proteins bind and activate PDGF receptor tyrosine kinases, which play a role in a wide range of developmental processes. Mutations in this gene are associated with meningioma. Reciprocal translocations between chromosomes 22 and 17, at sites where this gene and that for collagen type 1, alpha 1 are located, are associated with dermatofibrosarcoma protuberans, a rare skin tumor. Alternative splicing results in multiple transcript variants. [provided by RefSeq, Oct 2015]'}], 'n_matches': 1}
# >>> n_matches 1
# RESET GRAPH CLICKED
# RESET GRAPH CLICKED
# No gene annotation match for label: Platelet releasate secretory granule proteins
# ANNOT: {'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'uniprot_id': 'NA', 'refseq_summary': 'NA', 'synonyms': 'NA', 'matches': [], 'n_matches': 0}
# matches: []
# n_matches: 0
# >>> info_data {'id': 'Protein267', 'label': 'Platelet releasate secretory granule proteins', 'biopax_type': 'Protein', 'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'gene_type': 'NA', 'uniprot_id': 'NA', 'synonyms': 'NA', 'refseq_summary': 'NA', 'lfc': 'NA', 'fdr': 'NA', 'matches': [], 'n_matches': 0}
# No gene annotation match for label: Release of Calumenin
# ANNOT: {'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'uniprot_id': 'NA', 'refseq_summary': 'NA', 'synonyms': 'NA', 'matches': [], 'n_matches': 0}
# matches: []
# n_matches: 0
# >>> info_data {'id': 'BiochemicalReaction9', 'label': 'Release of Calumenin', 'biopax_type': 'BiochemicalReaction', 'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'gene_type': 'NA', 'uniprot_id': 'NA', 'synonyms': 'NA', 'refseq_summary': 'NA', 'lfc': 'NA', 'fdr': 'NA', 'matches': [], 'n_matches': 0}
# ANNOT: {'alias': 'CALU', 'symbol': 'CALU', 'ensembl_id': 'ENSG00000128595', 'name': 'calumenin', 'uniprot_id': 'O43852', 'refseq_summary': 'The product of this gene is a calcium-binding protein localized in the endoplasmic reticulum (ER) and it is involved in such ER functions as protein folding and sorting. This protein belongs to a family of multiple EF-hand proteins (CERC) that include reticulocalbin, ERC-55, and Cab45 and the product of this gene. Alternatively spliced transcript variants encoding different isoforms have been identified. [provided by RefSeq, Oct 2008]', 'matches': [{'alias': 'CALU', 'symbol': 'CALU', 'ensembl_id': 'ENSG00000128595', 'name': 'calumenin', 'uniprot_id': 'O43852', 'refseq_summary': 'The product of this gene is a calcium-binding protein localized in the endoplasmic reticulum (ER) and it is involved in such ER functions as protein folding and sorting. This protein belongs to a family of multiple EF-hand proteins (CERC) that include reticulocalbin, ERC-55, and Cab45 and the product of this gene. Alternatively spliced transcript variants encoding different isoforms have been identified. [provided by RefSeq, Oct 2008]'}], 'n_matches': 1}
# matches: [{'alias': 'CALU', 'symbol': 'CALU', 'ensembl_id': 'ENSG00000128595', 'name': 'calumenin', 'uniprot_id': 'O43852', 'refseq_summary': 'The product of this gene is a calcium-binding protein localized in the endoplasmic reticulum (ER) and it is involved in such ER functions as protein folding and sorting. This protein belongs to a family of multiple EF-hand proteins (CERC) that include reticulocalbin, ERC-55, and Cab45 and the product of this gene. Alternatively spliced transcript variants encoding different isoforms have been identified. [provided by RefSeq, Oct 2008]'}]
# n_matches: 1
# >>> info_data {'id': 'Protein276', 'label': 'CALU', 'biopax_type': 'Protein', 'ensembl_id': 'ENSG00000128595', 'symbol': 'CALU', 'name': 'calumenin', 'gene_type': 'NA', 'uniprot_id': 'O43852', 'synonyms': 'CALU', 'refseq_summary': 'The product of this gene is a calcium-binding protein localized in the endoplasmic reticulum (ER) and it is involved in such ER functions as protein folding and sorting. This protein belongs to a family of multiple EF-hand proteins (CERC) that include reticulocalbin, ERC-55, and Cab45 and the product of this gene. Alternatively spliced transcript variants encoding different isoforms have been identified. [provided by RefSeq, Oct 2008]', 'lfc': 'NA', 'fdr': 'NA', 'matches': [{'alias': 'CALU', 'symbol': 'CALU', 'ensembl_id': 'ENSG00000128595', 'name': 'calumenin', 'uniprot_id': 'O43852', 'refseq_summary': 'The product of this gene is a calcium-binding protein localized in the endoplasmic reticulum (ER) and it is involved in such ER functions as protein folding and sorting. This protein belongs to a family of multiple EF-hand proteins (CERC) that include reticulocalbin, ERC-55, and Cab45 and the product of this gene. Alternatively spliced transcript variants encoding different isoforms have been identified. [provided by RefSeq, Oct 2008]'}], 'n_matches': 1}
# >>> n_matches 1
# No gene annotation match for label: Release of platelet cytosolic components
# ANNOT: {'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'uniprot_id': 'NA', 'refseq_summary': 'NA', 'synonyms': 'NA', 'matches': [], 'n_matches': 0}
# matches: []
# n_matches: 0
# >>> info_data {'id': 'BiochemicalReaction6', 'label': 'Release of platelet cytosolic components', 'biopax_type': 'BiochemicalReaction', 'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'gene_type': 'NA', 'uniprot_id': 'NA', 'synonyms': 'NA', 'refseq_summary': 'NA', 'lfc': 'NA', 'fdr': 'NA', 'matches': [], 'n_matches': 0}
# No gene annotation match for label: Platelet releasate cytosolic proteins
# ANNOT: {'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'uniprot_id': 'NA', 'refseq_summary': 'NA', 'synonyms': 'NA', 'matches': [], 'n_matches': 0}
# matches: []
# n_matches: 0
# >>> info_data {'id': 'Protein221', 'label': 'Platelet releasate cytosolic proteins', 'biopax_type': 'Protein', 'ensembl_id': 'NA', 'symbol': 'NA', 'name': 'NA', 'gene_type': 'NA', 'uniprot_id': 'NA', 'synonyms': 'NA', 'refseq_summary': 'NA', 'lfc': 'NA', 'fdr': 'NA', 'matches': [], 'n_matches': 0}
# RESET GRAPH CLICKED
# RESET GRAPH CLICKED
