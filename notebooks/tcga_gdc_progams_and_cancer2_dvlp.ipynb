# %%
# !python --version
# Out:
# Python 3.11.14

# %% [markdown]
# ## GDC
#
# https://docs.gdc.cancer.gov/API/Users_Guide/Downloading_Files/
#
# sample
#  ├── primary_site       (organ)
#  ├── disease_type       (broad class)
#  ├── subtype_global     (cross-cancer)
#  ├── subtype_tissue     (within-cancer)
#  └── histology          (biological family)

# %% [markdown]
# ### TCGA / GDC Portal
#
# https://portal.gdc.cancer.gov/

# %%
import os, sys
import pandas as pd

from pathlib import Path

ROOT = Path().resolve().parent.parent
SRC = os.path.join(ROOT, "src")

if str(SRC) not in sys.path:
    sys.path.append(str(SRC))

print("ROOT:", ROOT)
print("SRC added:", SRC)

from libs.tcga_gdc_lib import *
from libs.Basic import *
# Out:
# ROOT: /home/flavio/uv
# SRC added: /home/flavio/uv/src

# %% [markdown]
# ### Defaults

# %%
ROOT = Path().resolve().parent
root_data = os.path.join(ROOT, "data/tcga")

gdc = GDC(root_data=root_data)

os.listdir(root_data)
# Out:
# ['subtype_for_TCGA-KIRC.tsv',
#  'cases_for_TCGA-LUSC.tsv',
#  'subtype_for_TCGA-HNSC.tsv',
#  'cases_for_TCGA-PCPG.tsv',
#  'cases_for_TCGA-THYM.tsv',
#  'cases_for_TCGA-PAAD.tsv',
#  'cases_for_TCGA-LAML.tsv',
#  'cases_for_TCGA-LIHC.tsv',
#  'subtype_for_TCGA-KIRP.tsv',
#  'subtype_for_TCGA-CHOL.tsv',
#  'cases_for_TCGA-MESO.tsv',
#  'cases_for_TCGA-BLCA.tsv',
#  'cases_for_TCGA-KIRP.tsv',
#  'cases_for_TCGA-LGG.tsv',
#  'cases_for_TCGA-ESCA.tsv',
#  'cases_for_TCGA-GBM.tsv',
#  'subtype_for_TCGA-ACC.tsv',
#  'cases_for_TCGA-TGCT.tsv',
#  'subtype_for_TCGA-MESO.tsv',
#  'subtype_for_TCGA-OV.tsv',
#  'cases_for_TCGA-UCEC.tsv',
#  'cases_for_TCGA-HNSC.tsv',
#  'subtype_for_TCGA-THYM.tsv',
#  'cases_for_TCGA-COAD.tsv',
#  'cases_for_TCGA-BRCA.tsv',
#  'subtype_for_TCGA-READ.tsv',
#  'subtype_for_TCGA-PAAD.tsv',
#  'subtype_for_TCGA-CESC.tsv',
#  'cases_for_TCGA-READ.tsv',
#  'cases_for_TCGA-DLBC.tsv',
#  'subtype_for_TCGA-PCPG.tsv',
#  'programs.txt',
#  'subtype_for_TCGA-SKCM.tsv',
#  'samples_for_TCGA-BRCA_other_other_other_Stage_IV.tsv',
#  'subtype_for_TCGA-PRAD.tsv',
#  'subtype_for_TCGA-LUAD.tsv',
#  'subtype_for_TCGA-LAML.tsv',
#  'subtype_for_TCGA-THCA.tsv',
#  'primary_site_program_TCGA.tsv',
#  'cases_for_TCGA-CHOL.tsv',
#  'subtype_for_TCGA-TGCT.tsv',
#  'subtype_for_TCGA-STAD.tsv',
#  'cases_for_TCGA-THCA.tsv',
#  'cases_for_TCGA-KICH.tsv',
#  'subtype_for_TCGA-DLBC.tsv',
#  'cases_for_TCGA-ACC.tsv',
#  'subtype_for_TCGA-UVM.tsv',
#  'subtype_for_TCGA-LUSC.tsv',
#  'cases_for_TCGA-LUAD.tsv',
#  'cases_for_TCGA-STAD.tsv',
#  'subtype_for_TCGA-BRCA.tsv',
#  'subtype_for_TCGA-UCEC.tsv',
#  'cases_for_TCGA-SARC.tsv',
#  'cases_for_TCGA-UCS.tsv',
#  'cases_for_TCGA-KIRC.tsv',
#  'cases_for_TCGA-SKCM.tsv',
#  'subtype_for_TCGA-SARC.tsv',
#  'subtype_for_TCGA-LIHC.tsv',
#  'subtype_for_TCGA-KICH.tsv',
#  'subtype_for_TCGA-UCS.tsv',
#  'subtype_for_TCGA-ESCA.tsv',
#  'subtype_for_TCGA-GBM.tsv',
#  'cases_for_TCGA-CESC.tsv',
#  'subtype_for_TCGA-COAD.tsv',
#  'subtype_for_TCGA-BLCA.tsv',
#  'cases_for_TCGA-UVM.tsv',
#  'subtype_for_TCGA-LGG.tsv',
#  'cases_for_TCGA-OV.tsv',
#  'cases_for_TCGA-PRAD.tsv']

# %% [markdown]
# ### Methods
#
# #### Get GDC programs - get_gdc_progams()
#
# > end_point: url_gdc_project = "https://api.gdc.cancer.gov/projects"
# > "facets": "program.name"
#
# #### Get valid primary sites - get_primary_sites()
#
# > end_point: url_gdc_project = "https://api.gdc.cancer.gov/projects"
# > "fields": "project_id,name,primary_site,disease_type"
#
# #### Get valid subtypes - get_subtypes()
#
# > end_point: url_gdc_cases = "https://api.gdc.cancer.gov/cases"
# > facets = "diagnoses.primary_diagnosis"
#
# #### For each subtype → get stages  - get_stages()
#
# > end_point: url_gdc_cases = "https://api.gdc.cancer.gov/cases"
# > "field": "diagnoses.ajcc_pathologic_stage" - AJCC diagnoses
#
# #### For each (subtype, stage) → get_samples()
#
# > end_point: url_gdc_cases = "https://api.gdc.cancer.gov/cases"
# > given pid, subtype, stage
# > from cases
# > "samples.sample_id", "samples.submitter_id", "samples.sample_type"
#
# #### get RNA-seq files - get_expression_files_given_samples()
#
# > given: "field": "cases.case_id", "value": case_ids
# > end_point: url_gdc_files = "https://api.gdc.cancer.gov/files"

# %% [markdown]
# ### Get all programs

# %%
force=False
verbose=True

prog_list = gdc.get_gdc_progams(force=force, verbose=verbose)
# Out:
# File read at '/home/flavio/uv/perturb_agent/data/tcga/programs.txt'

# %%
np.array(prog_list)
# Out:
# array(['TCGA', 'MATCH', 'TARGET', 'CGCI', 'CMI', 'APOLLO', 'BEATAML1.0',
#        'CPTAC', 'MP2PRT', 'ALCHEMIST', 'CCDI', 'CCG', 'CDDP_EAGLE',
#        'CTSP', 'EXCEPTIONAL_RESPONDERS', 'FM', 'HCMI', 'MMRF', 'NCICCR',
#        'OHSU', 'ORGANOID', 'RC', 'REBC', 'TRIO', 'VAREPOP', 'WCDT'],
#       dtype='<U22')

# %% [markdown]
# ### Primary sites given a program

# %%
gdc.url_gdc_project
# Out:
# 'https://api.gdc.cancer.gov/projects'

# %%
force=False
verbose=True

program = 'TCGA'

dfc = gdc.get_primary_sites(program=program, force=force, verbose=verbose)

print(len(dfc))
dfc.head(12)
# Out:
# Table opened ((33, 5)) at '/home/flavio/uv/perturb_agent/data/tcga/primary_site_program_TCGA.tsv'
# 33
#           pid                                       primary_site project_id  \
# 0    TCGA-ACC                                      Adrenal gland   TCGA-ACC
# 1   TCGA-PCPG  Adrenal gland, Retroperitoneum and peritoneum,...  TCGA-PCPG
# 2   TCGA-BLCA                                            Bladder  TCGA-BLCA
# 3    TCGA-LGG                                              Brain   TCGA-LGG
# 4    TCGA-GBM                                              Brain   TCGA-GBM
# 5   TCGA-BRCA                                             Breast  TCGA-BRCA
# 6   TCGA-LUAD                                  Bronchus and lung  TCGA-LUAD
# 7   TCGA-LUSC                                  Bronchus and lung  TCGA-LUSC
# 8   TCGA-MESO  Bronchus and lung, Heart, mediastinum, and pleura  TCGA-MESO
# 9   TCGA-CESC                                Cervix uteri, Ovary  TCGA-CESC
# 10  TCGA-COAD                       Colon, Rectosigmoid junction  TCGA-COAD
# 11  TCGA-READ  Colon, Rectosigmoid junction, Rectum, Connecti...  TCGA-READ
#
#                                          disease_type  \
# 0                        Adenomas and Adenocarcinomas
# 1                    Paragangliomas and Glomus Tumors
# 2   Epithelial Neoplasms, NOS, Squamous Cell Neopl...
# 3                                             Gliomas
# 4                               Not Reported, Gliomas
# 5   Adnexal and Skin Appendage Neoplasms, Adenomas...
# 6   Ductal and Lobular Neoplasms, Cystic, Mucinous...
# 7   Squamous Cell Neoplasms, Adenomas and Adenocar...
# 8                               Mesothelial Neoplasms
# 9   Squamous Cell Neoplasms, Cystic, Mucinous and ...
# 10  Cystic, Mucinous and Serous Neoplasms, Complex...
# 11  Cystic, Mucinous and Serous Neoplasms, Adenoma...
#
#                                                  name
# 0                            Adrenocortical Carcinoma
# 1                  Pheochromocytoma and Paraganglioma
# 2                        Bladder Urothelial Carcinoma
# 3                            Brain Lower Grade Glioma
# 4                             Glioblastoma Multiforme
# 5                           Breast Invasive Carcinoma
# 6                                 Lung Adenocarcinoma
# 7                        Lung Squamous Cell Carcinoma
# 8                                        Mesothelioma
# 9   Cervical Squamous Cell Carcinoma and Endocervi...
# 10                               Colon Adenocarcinoma
# 11                              Rectum Adenocarcinoma

# %%
dfc.tail(3)
# Out:
#           pid               primary_site project_id  \
# 30  TCGA-THCA              Thyroid gland  TCGA-THCA
# 31   TCGA-UCS  Uterus, NOS, Corpus uteri   TCGA-UCS
# 32  TCGA-UCEC  Uterus, NOS, Corpus uteri  TCGA-UCEC
#
#                                          disease_type  \
# 30  Squamous Cell Neoplasms, Epithelial Neoplasms,...
# 31  Basal Cell Neoplasms, Complex Mixed and Stroma...
# 32  Not Reported, Cystic, Mucinous and Serous Neop...
#
#                                     name
# 30                     Thyroid Carcinoma
# 31                Uterine Carcinosarcoma
# 32  Uterine Corpus Endometrial Carcinoma

# %% [markdown]
# ### Subtypes explanation
#
# 👉 GDC does NOT give you clean biological subtypes
# 👉 You must derive them yourself
#
# This is actually a feature, not a bug — because:
#
# > you control granularity
# > you can harmonize across cancers
# > you avoid noisy labels
#
#
# 💡 If you want to level this up
#
# I can help you build:
#
# 🔬 A cross-TCGA subtype harmonizer
# maps all projects → unified subtype ontology
# handles synonyms (adenocarcinoma, NOS, etc.)
# outputs clean ML-ready labels
#
# 👉 That would massively improve your perturbation analysis.

# %%
i = 5
pid = dfc.iloc[i].pid
primary_site = dfc.iloc[i].primary_site

print(i, pid, primary_site)
# Out:
# 5 TCGA-BRCA Breast

# %% [markdown]
# - Brain tumors do NOT use AJCC staging (3 - TCGA-LGG Brain)

# %%
force=False
verbose=True

i = 5
pid = dfc.iloc[i].pid
primary_site = dfc.iloc[i].primary_site

print(i, pid, primary_site)

df_cases, df_subt, df_prof = gdc.get_cases_and_subtypes(pid=pid, batch_size=200, do_filter=False, force=force, verbose=verbose)

print("df_cases", len(df_cases), "df_subt", len(df_subt))
df_subt
# Out:
# 5 TCGA-BRCA Breast
# Table opened ((1098, 24)) at '/home/flavio/uv/perturb_agent/data/tcga/cases_for_TCGA-BRCA.tsv'
# df_cases 1098 df_subt 12
#           pid          subtype_global           tumor_class  \
# 0   TCGA-BRCA                   other                 other
# 1   TCGA-BRCA                 lobular                 other
# 2   TCGA-BRCA                   other                 other
# 3   TCGA-BRCA                   other                 other
# 4   TCGA-BRCA                   other                 other
# 5   TCGA-BRCA  adenocarcinoma_generic        adenocarcinoma
# 6   TCGA-BRCA                   other                 other
# 7   TCGA-BRCA                  ductal        adenocarcinoma
# 8   TCGA-BRCA                  ductal                 other
# 9   TCGA-BRCA              clear_cell                 other
# 10  TCGA-BRCA                  ductal                 other
# 11  TCGA-BRCA          neuroendocrine  neuroendocrine_tumor
#
#             subtype_tissue   sstage    n
# 0                    other       II  447
# 1           breast_lobular  missing  223
# 2                    other      III  154
# 3                    other        I  141
# 4                    other  missing   85
# 5   adenocarcinoma_generic  missing   19
# 6                    other       IV   16
# 7            breast_ductal  missing    6
# 8            breast_ductal       II    2
# 9               clear_cell       II    2
# 10           breast_ductal  missing    2
# 11          neuroendocrine  missing    1

# %%
cols = ["pid", "case_id", "subtype_global", "tumor_class", "subtype_tissue", "stage"]

df_cases[cols].head(12)
# Out:
#           pid                               case_id subtype_global  \
# 0   TCGA-BRCA  e3935ce4-64d3-4a66-ba11-d308b844b410          other
# 1   TCGA-BRCA  e3b555aa-7f0a-49c6-9b13-182c61a144c1          other
# 2   TCGA-BRCA  17ca61a2-607a-45ff-88fa-ef72e80bf891          other
# 3   TCGA-BRCA  7d681cc6-689d-41c8-9e84-e13733089ec9          other
# 4   TCGA-BRCA  17f275c1-a0d4-487d-8f02-ea279584b4cd          other
# 5   TCGA-BRCA  189e1f27-7738-413a-a4d4-97d41d592a13          other
# 6   TCGA-BRCA  95c53ecf-d8f1-4bcb-9b1a-c9a0542939f0          other
# 7   TCGA-BRCA  c0f88fc5-56b0-4255-bbd1-9a21ced8b37b          other
# 8   TCGA-BRCA  0f64edec-0f1f-4025-8a53-75f9534f7828          other
# 9   TCGA-BRCA  c25898b4-eb33-42f4-bf3f-bf532a929e7d        lobular
# 10  TCGA-BRCA  195b6731-6ae6-416e-a345-0eb8874a0ca2          other
# 11  TCGA-BRCA  7f97971b-2818-4e4b-9c9e-7c0246f9484c          other
#
#    tumor_class  subtype_tissue       stage
# 0        other           other     unknown
# 1        other           other  Stage IIIA
# 2        other           other    Stage IA
# 3        other           other   Stage IIB
# 4        other           other    Stage IA
# 5        other           other   Stage IIA
# 6        other           other    Stage IA
# 7        other           other  Stage IIIA
# 8        other           other   Stage IIA
# 9        other  breast_lobular     unknown
# 10       other           other  Stage IIIA
# 11       other           other   Stage IIB

# %% [markdown]
# ### Get all cases and their classifications

# %%
force=False
verbose=True

run_all = False

if run_all:

    for i in range(len(dfc)):
        print(i, end=' ')
        pid = dfc.iloc[i].pid
        primary_site = dfc.iloc[i].primary_site

        print(pid, primary_site)

        df_cases, df_subt, df_prof = gdc.get_cases_and_subtypes(pid=pid, batch_size=200, do_filter=False, force=force, verbose=verbose)

# %% [markdown]
# ### Search for samples and files for each case given
#
# - input: pid, subtype_global, tumor_class, subtype_tissue, and stage

# %%
force=False
verbose=True

i = 5
pid = dfc.iloc[i].pid
primary_site = dfc.iloc[i].primary_site

print(i, pid, primary_site)

df_cases, df_subt, df_prof = gdc.get_cases_and_subtypes(pid=pid, batch_size=200, do_filter=False, force=force, verbose=verbose)
df_subt
# Out:
# 5 TCGA-BRCA Breast
# Table opened ((1098, 24)) at '/home/flavio/uv/perturb_agent/data/tcga/cases_for_TCGA-BRCA.tsv'
#           pid          subtype_global           tumor_class  \
# 0   TCGA-BRCA                   other                 other
# 1   TCGA-BRCA                 lobular                 other
# 2   TCGA-BRCA                   other                 other
# 3   TCGA-BRCA                   other                 other
# 4   TCGA-BRCA                   other                 other
# 5   TCGA-BRCA  adenocarcinoma_generic        adenocarcinoma
# 6   TCGA-BRCA                   other                 other
# 7   TCGA-BRCA                  ductal        adenocarcinoma
# 8   TCGA-BRCA                  ductal                 other
# 9   TCGA-BRCA              clear_cell                 other
# 10  TCGA-BRCA                  ductal                 other
# 11  TCGA-BRCA          neuroendocrine  neuroendocrine_tumor
#
#             subtype_tissue   sstage    n
# 0                    other       II  447
# 1           breast_lobular  missing  223
# 2                    other      III  154
# 3                    other        I  141
# 4                    other  missing   85
# 5   adenocarcinoma_generic  missing   19
# 6                    other       IV   16
# 7            breast_ductal  missing    6
# 8            breast_ductal       II    2
# 9               clear_cell       II    2
# 10           breast_ductal  missing    2
# 11          neuroendocrine  missing    1

# %%
i = 6
df_subt.iloc[i]
# Out:
# pid               TCGA-BRCA
# subtype_global        other
# tumor_class           other
# subtype_tissue        other
# sstage                   IV
# n                        16
# Name: 6, dtype: object

# %%
force=False
verbose=True

i = 6
row = df_subt.iloc[i]

pid = row.pid
subtype_global = row.subtype_global
tumor_class = row.tumor_class
subtype_tissue = row.subtype_tissue
sstage = row.sstage

s_case = f"{pid} subtype '{subtype_global}' tumor '{tumor_class}' subtype_tissue '{subtype_tissue}' stage '{sstage}'"
print(s_case)

df_sample = gdc.get_samples_for_pid_subtypes(pid=pid, subtype_global=subtype_global,
                                             tumor_class=tumor_class, subtype_tissue=subtype_tissue,
                                             sstage=sstage, batch_size=200,
                                             force=force, verbose=verbose)

print(len(df_sample))

df_sample.head(3)
# Out:
# TCGA-BRCA subtype 'other' tumor 'other' subtype_tissue 'other' stage 'IV'
# Table opened ((1098, 24)) at '/home/flavio/uv/perturb_agent/data/tcga/cases_for_TCGA-BRCA.tsv'
# Table opened ((445, 11)) at '/home/flavio/uv/perturb_agent/data/tcga/samples_for_TCGA-BRCA_other_other_other_Stage_IV.tsv'
# 445
#                                 case_id                             sample_id  \
# 0  32bc7cc4-d185-4594-bbee-4b96410be512  4ab5f84d-7ba2-49e2-862b-48ff8cff3c34
# 1  32bc7cc4-d185-4594-bbee-4b96410be512  4ab5f84d-7ba2-49e2-862b-48ff8cff3c34
# 2  32bc7cc4-d185-4594-bbee-4b96410be512  4ab5f84d-7ba2-49e2-862b-48ff8cff3c34
#
#      sample_type                               file_id  \
# 0  Primary Tumor  a2db9935-0427-49f1-97c0-41db6d012889
# 1  Primary Tumor  6b2fc2ac-a4b4-4e33-9ecc-8f3f98d4e33e
# 2  Primary Tumor  125aede6-ea2e-4f2d-a8f1-31b9ec3464dd
#
#                                            file_name  \
# 0          TCGA-A8-A08T-01A-11-A13A-20_RPPA_data.tsv
# 1  TCGA-BRCA.dfe66ee6-0535-42b6-b6b1-b961604d8a27...
# 2  TCGA_BRCA.ed76da0d-850e-4017-8bd4-f2e9e90d27f1...
#
#                              data_type        pid subtype_global tumor_class  \
# 0    Protein Expression Quantification  TCGA-BRCA          other       other
# 1  Allele-specific Copy Number Segment  TCGA-BRCA          other       other
# 2           Annotated Somatic Mutation  TCGA-BRCA          other       other
#
#   subtype_tissue     stage
# 0          other  Stage IV
# 1          other  Stage IV
# 2          other  Stage IV

# %%
dfu = gdc.group_file_types(df_sample)
dfu
# Out:
#                               data_type   n
# 0            Annotated Somatic Mutation  92
# 1           Raw Simple Somatic Mutation  64
# 2                         Aligned Reads  42
# 3              Structural Rearrangement  32
# 4                     Transcript Fusion  24
# 5                Gene Level Copy Number  24
# 6   Allele-specific Copy Number Segment  20
# 7                           Slide Image  19
# 8                   Copy Number Segment  18
# 9                    Masked Intensities  12
# 10                      Raw Intensities  10
# 11          Aggregated Somatic Mutation  10
# 12              Masked Somatic Mutation  10
# 13            Simple Germline Variation  10
# 14           Masked Copy Number Segment  10
# 15        Intermediate Analysis Archive   8
# 16       Gene Expression Quantification   6
# 17       Splice Junction Quantification   6
# 18               Methylation Beta Value   6
# 19      miRNA Expression Quantification   6
# 20    Isoform Expression Quantification   6
# 21    Protein Expression Quantification   5
# 22                     Pathology Report   5

# %%
lista = list(dfu.data_type)
lista.sort()

"; ".join(lista)
# Out:
# 'Aggregated Somatic Mutation; Aligned Reads; Allele-specific Copy Number Segment; Annotated Somatic Mutation; Copy Number Segment; Gene Expression Quantification; Gene Level Copy Number; Intermediate Analysis Archive; Isoform Expression Quantification; Masked Copy Number Segment; Masked Intensities; Masked Somatic Mutation; Methylation Beta Value; Pathology Report; Protein Expression Quantification; Raw Intensities; Raw Simple Somatic Mutation; Simple Germline Variation; Slide Image; Splice Junction Quantification; Structural Rearrangement; Transcript Fusion; miRNA Expression Quantification'

# %% [markdown]
# ### Testing loop

# %%
N_cases = 54
batch_cases=5

ini = -batch_cases
end = 0

while(True):
    ini += batch_cases
    end += batch_cases
                
    if ini >= N_cases: break
    if end > N_cases:
        end = N_cases

    print(f"{ini}-{end}")
# Out:
# 0-5
# 5-10
# 10-15
# 15-20
# 20-25
# 25-30
# 30-35
# 35-40
# 40-45
# 45-50
# 50-54

# %% [markdown]
# ### Get Any table (for tumor and control)

# %%
force=False
verbose=True

i=0
row = df_sample.iloc[i]

pid = row.pid
case_id = row.case_id
file_type = row.data_type
file_id = row.file_id
sample_type = row.sample_type
stage = row.stage


print(f"{pid}, {case_id}, {file_type}, {file_id}")

dft = gdc.get_table_given_fileID(pid=pid, case_id=case_id, 
                                 file_type=file_type, sample_type=sample_type, stage=stage, file_id=file_id, 
                                 force=force, verbose=verbose)
print(len(dft))
dft.head(6)
# Out:
# TCGA-BRCA, 32bc7cc4-d185-4594-bbee-4b96410be512, Protein Expression Quantification, a2db9935-0427-49f1-97c0-41db6d012889
# Searching: Table opened ((487, 6)) at '/home/flavio/uv/perturb_agent/data/tcga/Protein_Expression_Quantification_for_TCGA-BRCA_case_32bc7cc4-d185-4594-bbee-4b96410be512_sample_type_Primary_Tumor_stage_Stage_IV_fileid_a2db9935-0427-49f1-97c0-41db6d012889.tsv'
# found 487 files in selected samples.
# 487
#         AGID  lab_id catalog_number set_id peptide_target  protein_expression
# 0  AGID00100     882         sc-628    Old       1433BETA           -0.018320
# 1  AGID00111     913       sc-23957    Old    1433EPSILON           -0.036071
# 2  AGID00101     883        sc-1019    Old       1433ZETA            0.387080
# 3  AGID00001       2           9452    Old          4EBP1            0.016983
# 4  AGID00002       3           9456    Old     4EBP1_pS65           -0.604880
# 5  AGID00003       6           9459    Old  4EBP1_pT37T46            0.056122

# %% [markdown]
# ### Get Expression table (for tumor and control)
#
# #### 🧪 Mental model (important)
#
# | Step	|  Needs strand? | Output | Column |
# |---------|---------|---------|---------|
# | Read assignment	|  YES |  counts | stranded_first |
# | Normalization	| NO | TPM / FPKM | both: unstranded |
# | Biological meaning | NO | gene expression| both: unstranded |

# %%
file_type = 'Gene Expression Quantification'

force=True
verbose=True

dft = pd.DataFrame()

df2 = df_sample[df_sample.data_type == file_type]

for i, row in df2.iterrows():
    pid = row.pid
    case_id = row.case_id
    file_type = row.data_type
    file_id = row.file_id
    sample_type = row.sample_type
    stage = row.stage

    print(f"{i}) {pid}, {case_id}, {file_type}, {file_id}")

    dft = gdc.get_table_given_fileID(pid=pid, case_id=case_id, 
                                     sample_type=sample_type, stage=stage, 
                                     file_type=file_type, file_id=file_id, 
                                     force=force, verbose=verbose)


dft.head(6)
# Out:
# 8) TCGA-BRCA, 32bc7cc4-d185-4594-bbee-4b96410be512, Gene Expression Quantification, 8603da6b-3bb9-4fff-b409-c5af2afd53b3
# Searching: Table saved ((60660, 9)) at '/home/flavio/uv/perturb_agent/data/tcga/Gene_Expression_Quantification_for_TCGA-BRCA_case_32bc7cc4-d185-4594-bbee-4b96410be512_sample_type_Primary_Tumor_stage_Stage_IV_fileid_8603da6b-3bb9-4fff-b409-c5af2afd53b3.tsv'
# found 60660 files in selected samples.
# 129) TCGA-BRCA, 1783cac1-253a-40af-a9ac-48dfb20e1ab8, Gene Expression Quantification, 9985bb0b-d1cc-455b-80d9-f8007669cd5c
# Searching: Table saved ((60660, 9)) at '/home/flavio/uv/perturb_agent/data/tcga/Gene_Expression_Quantification_for_TCGA-BRCA_case_1783cac1-253a-40af-a9ac-48dfb20e1ab8_sample_type_Solid_Tissue_Normal_stage_Stage_IV_fileid_9985bb0b-d1cc-455b-80d9-f8007669cd5c.tsv'
# found 60660 files in selected samples.
# 175) TCGA-BRCA, 1783cac1-253a-40af-a9ac-48dfb20e1ab8, Gene Expression Quantification, 451ecdf8-433f-4d38-8ab6-3cc8d428ed95
# Searching: Table saved ((60660, 9)) at '/home/flavio/uv/perturb_agent/data/tcga/Gene_Expression_Quantification_for_TCGA-BRCA_case_1783cac1-253a-40af-a9ac-48dfb20e1ab8_sample_type_Primary_Tumor_stage_Stage_IV_fileid_451ecdf8-433f-4d38-8ab6-3cc8d428ed95.tsv'
# found 60660 files in selected samples.
# 186) TCGA-BRCA, 157ec9e0-ca6e-4da1-9233-f976cf0db433, Gene Expression Quantification, a127fb1e-aa3b-4b6d-98b5-c141ffba9ae7
# Searching: Table saved ((60660, 9)) at '/home/flavio/uv/perturb_agent/data/tcga/Gene_Expression_Quantification_for_TCGA-BRCA_case_157ec9e0-ca6e-4da1-9233-f976cf0db433_sample_type_Primary_Tumor_stage_Stage_IV_fileid_a127fb1e-aa3b-4b6d-98b5-c141ffba9ae7.tsv'
# found 60660 files in selected samples.
# 316) TCGA-BRCA, 128d198e-9b22-427c-90db-3714455f3a17, Gene Expression Quantification, 54600389-6de5-44ce-ada1-8a8508b50980
# Searching: Table saved ((60660, 9)) at '/home/flavio/uv/perturb_agent/data/tcga/Gene_Expression_Quantification_for_TCGA-BRCA_case_128d198e-9b22-427c-90db-3714455f3a17_sample_type_Primary_Tumor_stage_Stage_IV_fileid_54600389-6de5-44ce-ada1-8a8508b50980.tsv'
# found 60660 files in selected samples.
# 357) TCGA-BRCA, 01263518-5f7c-49dc-8d7e-84b0c03a6a63, Gene Expression Quantification, aa89d193-05a1-4f7f-9291-b9cf646656de
# Searching: Table saved ((60660, 9)) at '/home/flavio/uv/perturb_agent/data/tcga/Gene_Expression_Quantification_for_TCGA-BRCA_case_01263518-5f7c-49dc-8d7e-84b0c03a6a63_sample_type_Primary_Tumor_stage_Stage_IV_fileid_aa89d193-05a1-4f7f-9291-b9cf646656de.tsv'
# found 60660 files in selected samples.
#            gene_id    symbol       gene_type  unstranded  counts  \
# 4  ENSG00000000003    TSPAN6  protein_coding         911     446
# 5  ENSG00000000005      TNMD  protein_coding          22      12
# 6  ENSG00000000419      DPM1  protein_coding        4349    2189
# 7  ENSG00000000457     SCYL3  protein_coding        1420    1109
# 8  ENSG00000000460  C1orf112  protein_coding        1197    1075
# 9  ENSG00000000938       FGR  protein_coding         679     366
#
#    stranded_second  tpm_unstranded  fpkm_unstranded  fpkm_uq_unstranded
# 4              465         12.8633           3.2599              3.1661
# 5               10          0.9547           0.2419              0.2350
# 6             2160        230.7761          58.4850             56.8023
# 7             1155         13.2135           3.3487              3.2523
# 8             1036         12.8419           3.2545              3.1608
# 9              313         12.8589           3.2588              3.1650

# %%
np.unique(df_sample.data_type)
# Out:
# array(['Aggregated Somatic Mutation', 'Aligned Reads',
#        'Allele-specific Copy Number Segment',
#        'Annotated Somatic Mutation', 'Copy Number Segment',
#        'Gene Expression Quantification', 'Gene Level Copy Number',
#        'Intermediate Analysis Archive',
#        'Isoform Expression Quantification', 'Masked Copy Number Segment',
#        'Masked Intensities', 'Masked Somatic Mutation',
#        'Methylation Beta Value', 'Pathology Report',
#        'Protein Expression Quantification', 'Raw Intensities',
#        'Raw Simple Somatic Mutation', 'Simple Germline Variation',
#        'Slide Image', 'Splice Junction Quantification',
#        'Structural Rearrangement', 'Transcript Fusion',
#        'miRNA Expression Quantification'], dtype=object)

# %%
df_sample.columns
# Out:
# Index(['case_id', 'sample_id', 'sample_type', 'file_id', 'file_name',
#        'data_type', 'pid', 'subtype_global', 'tumor_class', 'subtype_tissue',
#        'stage'],
#       dtype='str')

# %%
case_id = '1783cac1-253a-40af-a9ac-48dfb20e1ab8'
data_type = 'Gene Expression Quantification'

df2 = df_sample[df_sample.data_type == data_type]
case_id_list = df2.case_id.unique()
print(f"There are {len(case_id_list)} unique case IDs")

print(len(df2))
df2
# Out:
# There are 5 unique case IDs
# 6
#                                   case_id  \
# 8    32bc7cc4-d185-4594-bbee-4b96410be512
# 129  1783cac1-253a-40af-a9ac-48dfb20e1ab8
# 175  1783cac1-253a-40af-a9ac-48dfb20e1ab8
# 186  157ec9e0-ca6e-4da1-9233-f976cf0db433
# 316  128d198e-9b22-427c-90db-3714455f3a17
# 357  01263518-5f7c-49dc-8d7e-84b0c03a6a63
#
#                                 sample_id          sample_type  \
# 8    4ab5f84d-7ba2-49e2-862b-48ff8cff3c34        Primary Tumor
# 129  c75bc2c7-cf1f-482c-b615-f60b56983124  Solid Tissue Normal
# 175  f0785dc2-a43e-4b59-a21c-ab55c490d441        Primary Tumor
# 186  e405d22f-86a6-4141-ae74-7098d0fdedfd        Primary Tumor
# 316  eeb8b594-1bba-4af3-be80-682e261965b4        Primary Tumor
# 357  5d1a5545-6934-41e5-b41b-8e0ee88e6ec6        Primary Tumor
#
#                                   file_id  \
# 8    8603da6b-3bb9-4fff-b409-c5af2afd53b3
# 129  9985bb0b-d1cc-455b-80d9-f8007669cd5c
# 175  451ecdf8-433f-4d38-8ab6-3cc8d428ed95
# 186  a127fb1e-aa3b-4b6d-98b5-c141ffba9ae7
# 316  54600389-6de5-44ce-ada1-8a8508b50980
# 357  aa89d193-05a1-4f7f-9291-b9cf646656de
#
#                                              file_name  \
# 8    3d31d7a9-76b8-41f4-a037-0dfe6a4ecb0c.rna_seq.a...
# 129  b3435d9e-fb7f-4748-9a0b-2b532875c87e.rna_seq.a...
# 175  d7eb3fb0-7bfe-4f69-b298-41dde09902e6.rna_seq.a...
# 186  e590db5d-2577-43ec-9d39-45a257be5562.rna_seq.a...
# 316  65ba302c-51a9-4493-8d28-e7bc076bca54.rna_seq.a...
# 357  e06580e9-0b4a-48f7-9522-d54229aefb2d.rna_seq.a...
#
#                           data_type        pid subtype_global tumor_class  \
# 8    Gene Expression Quantification  TCGA-BRCA          other       other
# 129  Gene Expression Quantification  TCGA-BRCA          other       other
# 175  Gene Expression Quantification  TCGA-BRCA          other       other
# 186  Gene Expression Quantification  TCGA-BRCA          other       other
# 316  Gene Expression Quantification  TCGA-BRCA          other       other
# 357  Gene Expression Quantification  TCGA-BRCA          other       other
#
#     subtype_tissue     stage
# 8            other  Stage IV
# 129          other  Stage IV
# 175          other  Stage IV
# 186          other  Stage IV
# 316          other  Stage IV
# 357          other  Stage IV

# %%
Counter(df2.sample_type)
# Out:
# Counter({'Primary Tumor': 5, 'Solid Tissue Normal': 1})

# %%
df_normal = df2[ [True if isinstance(x,str) and 'normal' in x.lower() else False for x in df2.sample_type] ]
print(len(df_normal))
df_normal
# Out:
# 1
#                                   case_id  \
# 129  1783cac1-253a-40af-a9ac-48dfb20e1ab8
#
#                                 sample_id          sample_type  \
# 129  c75bc2c7-cf1f-482c-b615-f60b56983124  Solid Tissue Normal
#
#                                   file_id  \
# 129  9985bb0b-d1cc-455b-80d9-f8007669cd5c
#
#                                              file_name  \
# 129  b3435d9e-fb7f-4748-9a0b-2b532875c87e.rna_seq.a...
#
#                           data_type        pid subtype_global tumor_class  \
# 129  Gene Expression Quantification  TCGA-BRCA          other       other
#
#     subtype_tissue     stage
# 129          other  Stage IV

# %%
df_tumor = df2[ [True if isinstance(x,str) and 'tumor' in x.lower() else False for x in df2.sample_type] ]
print(len(df_tumor))
df_tumor
# Out:
# 5
#                                   case_id  \
# 8    32bc7cc4-d185-4594-bbee-4b96410be512
# 175  1783cac1-253a-40af-a9ac-48dfb20e1ab8
# 186  157ec9e0-ca6e-4da1-9233-f976cf0db433
# 316  128d198e-9b22-427c-90db-3714455f3a17
# 357  01263518-5f7c-49dc-8d7e-84b0c03a6a63
#
#                                 sample_id    sample_type  \
# 8    4ab5f84d-7ba2-49e2-862b-48ff8cff3c34  Primary Tumor
# 175  f0785dc2-a43e-4b59-a21c-ab55c490d441  Primary Tumor
# 186  e405d22f-86a6-4141-ae74-7098d0fdedfd  Primary Tumor
# 316  eeb8b594-1bba-4af3-be80-682e261965b4  Primary Tumor
# 357  5d1a5545-6934-41e5-b41b-8e0ee88e6ec6  Primary Tumor
#
#                                   file_id  \
# 8    8603da6b-3bb9-4fff-b409-c5af2afd53b3
# 175  451ecdf8-433f-4d38-8ab6-3cc8d428ed95
# 186  a127fb1e-aa3b-4b6d-98b5-c141ffba9ae7
# 316  54600389-6de5-44ce-ada1-8a8508b50980
# 357  aa89d193-05a1-4f7f-9291-b9cf646656de
#
#                                              file_name  \
# 8    3d31d7a9-76b8-41f4-a037-0dfe6a4ecb0c.rna_seq.a...
# 175  d7eb3fb0-7bfe-4f69-b298-41dde09902e6.rna_seq.a...
# 186  e590db5d-2577-43ec-9d39-45a257be5562.rna_seq.a...
# 316  65ba302c-51a9-4493-8d28-e7bc076bca54.rna_seq.a...
# 357  e06580e9-0b4a-48f7-9522-d54229aefb2d.rna_seq.a...
#
#                           data_type        pid subtype_global tumor_class  \
# 8    Gene Expression Quantification  TCGA-BRCA          other       other
# 175  Gene Expression Quantification  TCGA-BRCA          other       other
# 186  Gene Expression Quantification  TCGA-BRCA          other       other
# 316  Gene Expression Quantification  TCGA-BRCA          other       other
# 357  Gene Expression Quantification  TCGA-BRCA          other       other
#
#     subtype_tissue     stage
# 8            other  Stage IV
# 175          other  Stage IV
# 186          other  Stage IV
# 316          other  Stage IV
# 357          other  Stage IV

# %%
cols = ['file_id', 'data_type', 'sample_type']
df_tumor2 = df_tumor[cols].copy().reset_index(drop=True)
df_tumor2
# Out:
#                                 file_id                       data_type  \
# 0  8603da6b-3bb9-4fff-b409-c5af2afd53b3  Gene Expression Quantification
# 1  451ecdf8-433f-4d38-8ab6-3cc8d428ed95  Gene Expression Quantification
# 2  a127fb1e-aa3b-4b6d-98b5-c141ffba9ae7  Gene Expression Quantification
# 3  54600389-6de5-44ce-ada1-8a8508b50980  Gene Expression Quantification
# 4  aa89d193-05a1-4f7f-9291-b9cf646656de  Gene Expression Quantification
#
#      sample_type
# 0  Primary Tumor
# 1  Primary Tumor
# 2  Primary Tumor
# 3  Primary Tumor
# 4  Primary Tumor

# %%
df_normal2 = df_normal[cols].copy().reset_index(drop=True)
df_normal2
# Out:
#                                 file_id                       data_type  \
# 0  9985bb0b-d1cc-455b-80d9-f8007669cd5c  Gene Expression Quantification
#
#            sample_type
# 0  Solid Tissue Normal

# %%
data_type2 = title_replace(data_type)

file_id = df_tumor2.iloc[0]['file_id']
files = [x for x in os.listdir(gdc.root_data) if file_id in x and data_type2 in x ]
files
# Out:
# ['Gene_Expression_Quantification_for_TCGA-BRCA_case_32bc7cc4-d185-4594-bbee-4b96410be512_sample_type_Primary_Tumor_stage_Stage_IV_fileid_8603da6b-3bb9-4fff-b409-c5af2afd53b3.tsv']

# %%
def get_table_searching_for_fileID(pid:str, data_type:str, sample_type:str, file_id:str,  verbose:bool=False) -> pd.DataFrame:
        
    data_type2 = title_replace(data_type)
    sample_type2 = title_replace(sample_type)

    files = [x for x in os.listdir(gdc.root_data) if file_id in x and data_type2 in x and sample_type2 in x]

    if len(files) == 0:
        print(f"No files found for {file_id}.")
        gdc.df_table = pd.DataFrame()
        return gdc.df_table

    if len(files) > 1:
        print(f"Multiple files found for {file_id}. Using the first one.")

    fname = files[0]
    df_table = pdreadcsv(fname, gdc.root_data, verbose=verbose)
    gdc.df_table = df_table

    return df_table

row = df_tumor2.iloc[0]
file_id = row['file_id']
sample_type = row['sample_type']
data_type = row['data_type']

dft = get_table_searching_for_fileID(pid=pid, data_type=data_type, sample_type=sample_type, file_id=file_id, verbose=verbose)
# Out:
# Table opened ((60660, 9)) at '/home/flavio/uv/perturb_agent/data/tcga/Gene_Expression_Quantification_for_TCGA-BRCA_case_32bc7cc4-d185-4594-bbee-4b96410be512_sample_type_Primary_Tumor_stage_Stage_IV_fileid_8603da6b-3bb9-4fff-b409-c5af2afd53b3.tsv'

# %%
print(len(dft))
dft.head(3)
# Out:
# 60660
#            gene_id  symbol       gene_type  unstranded  counts  \
# 0  ENSG00000000003  TSPAN6  protein_coding        3458    1714
# 1  ENSG00000000005    TNMD  protein_coding           6       3
# 2  ENSG00000000419    DPM1  protein_coding        1645     847
#
#    stranded_second  tpm_unstranded  fpkm_unstranded  fpkm_uq_unstranded
# 0             1744         44.5918          12.7433             12.2430
# 1                3          0.2378           0.0680              0.0653
# 2              798         79.7189          22.7818             21.8875

# %%
df2.head(2)
# Out:
#                                   case_id  \
# 8    32bc7cc4-d185-4594-bbee-4b96410be512
# 129  1783cac1-253a-40af-a9ac-48dfb20e1ab8
#
#                                 sample_id          sample_type  \
# 8    4ab5f84d-7ba2-49e2-862b-48ff8cff3c34        Primary Tumor
# 129  c75bc2c7-cf1f-482c-b615-f60b56983124  Solid Tissue Normal
#
#                                   file_id  \
# 8    8603da6b-3bb9-4fff-b409-c5af2afd53b3
# 129  9985bb0b-d1cc-455b-80d9-f8007669cd5c
#
#                                              file_name  \
# 8    3d31d7a9-76b8-41f4-a037-0dfe6a4ecb0c.rna_seq.a...
# 129  b3435d9e-fb7f-4748-9a0b-2b532875c87e.rna_seq.a...
#
#                           data_type        pid subtype_global tumor_class  \
# 8    Gene Expression Quantification  TCGA-BRCA          other       other
# 129  Gene Expression Quantification  TCGA-BRCA          other       other
#
#     subtype_tissue     stage
# 8            other  Stage IV
# 129          other  Stage IV

# %%
df_normal2
# Out:
#                                   file_id                       data_type  \
# 129  9985bb0b-d1cc-455b-80d9-f8007669cd5c  Gene Expression Quantification
#
#              sample_type
# 129  Solid Tissue Normal

# %%
df_tumor2
# Out:
#                                   file_id                       data_type  \
# 8    8603da6b-3bb9-4fff-b409-c5af2afd53b3  Gene Expression Quantification
# 175  451ecdf8-433f-4d38-8ab6-3cc8d428ed95  Gene Expression Quantification
# 186  a127fb1e-aa3b-4b6d-98b5-c141ffba9ae7  Gene Expression Quantification
# 316  54600389-6de5-44ce-ada1-8a8508b50980  Gene Expression Quantification
# 357  aa89d193-05a1-4f7f-9291-b9cf646656de  Gene Expression Quantification
#
#        sample_type
# 8    Primary Tumor
# 175  Primary Tumor
# 186  Primary Tumor
# 316  Primary Tumor
# 357  Primary Tumor

# %%
cols = ["gene_id", "symbol", "gene_type", "counts"]
common_cols = ["gene_id", "symbol", "gene_type"]

dfa_tumor = pd.DataFrame()

for i, row in df_tumor2.iterrows():
    data_type = row.data_type
    sample_type = row.sample_type
    file_id = row.file_id
    
    dft = get_table_searching_for_fileID(pid=pid, data_type=data_type, sample_type=sample_type, file_id=file_id, verbose=False)

    if dft.empty:
        print(f"No data found for file_id: {i} {file_id} {data_type} and {sample_type}")
        continue

    dft = dft[cols]
    dft = dft.rename(columns={"counts": f"counts_{i+1}"})

    if dfa_tumor.empty:
        dfa_tumor = dft
    else:
        dfa_tumor = dfa_tumor.merge(dft, on=common_cols, how="outer") 

print(len(dfa_tumor))
dfa_tumor.head(3)
# Out:
# 61980
#            gene_id  symbol       gene_type  counts_1  counts_2  counts_3  \
# 0  ENSG00000000003  TSPAN6  protein_coding      1714      2222       910
# 1  ENSG00000000005    TNMD  protein_coding         3        32         6
# 2  ENSG00000000419    DPM1  protein_coding       847      1045       917
#
#    counts_4  counts_5
# 0      1335       446
# 1         0        12
# 2      1584      2189

# %%
i=4
dfa_tumor.iloc[i:i+30]
# Out:
#             gene_id  symbol       gene_type  counts_1  counts_2  counts_3  \
# 30  ENSG00000002586    CD99  protein_coding      4530      7311         0
# 31  ENSG00000002586    CD99  protein_coding      4530         0      5235
# 32  ENSG00000002586    CD99  protein_coding      4530         0      5235
# 33  ENSG00000002586    CD99  protein_coding      4530         0      5235
# 34  ENSG00000002586    CD99  protein_coding      4530         0      5235
# 35  ENSG00000002586    CD99  protein_coding      4530         0         0
# 36  ENSG00000002586    CD99  protein_coding      4530         0         0
# 37  ENSG00000002586    CD99  protein_coding      4530         0         0
# 38  ENSG00000002586    CD99  protein_coding      4530         0         0
# 39  ENSG00000002586    CD99  protein_coding         0      7311      5235
# 40  ENSG00000002586    CD99  protein_coding         0      7311      5235
# 41  ENSG00000002586    CD99  protein_coding         0      7311      5235
# 42  ENSG00000002586    CD99  protein_coding         0      7311      5235
# 43  ENSG00000002586    CD99  protein_coding         0      7311         0
# 44  ENSG00000002586    CD99  protein_coding         0      7311         0
# 45  ENSG00000002586    CD99  protein_coding         0      7311         0
# 46  ENSG00000002586    CD99  protein_coding         0      7311         0
# 47  ENSG00000002586    CD99  protein_coding         0         0      5235
# 48  ENSG00000002586    CD99  protein_coding         0         0      5235
# 49  ENSG00000002586    CD99  protein_coding         0         0      5235
# 50  ENSG00000002586    CD99  protein_coding         0         0      5235
# 51  ENSG00000002586    CD99  protein_coding         0         0         0
# 52  ENSG00000002586    CD99  protein_coding         0         0         0
# 53  ENSG00000002586    CD99  protein_coding         0         0         0
# 54  ENSG00000002586    CD99  protein_coding         0         0         0
# 55  ENSG00000002587  HS3ST1  protein_coding        74       334        32
# 56  ENSG00000002726    AOC1  protein_coding        74        12         3
# 57  ENSG00000002745   WNT16  protein_coding         0         5         0
# 58  ENSG00000002746   HECW1  protein_coding        47        76         5
# 59  ENSG00000002822  MAD1L1  protein_coding         9        27         4
#
#     counts_4  counts_5
# 30         0         0
# 31      7003      3304
# 32      7003         0
# 33         0      3304
# 34         0         0
# 35      7003      3304
# 36      7003         0
# 37         0      3304
# 38         0         0
# 39      7003      3304
# 40      7003         0
# 41         0      3304
# 42         0         0
# 43      7003      3304
# 44      7003         0
# 45         0      3304
# 46         0         0
# 47      7003      3304
# 48      7003         0
# 49         0      3304
# 50         0         0
# 51      7003      3304
# 52      7003         0
# 53         0      3304
# 54         0         0
# 55       133       157
# 56         1        38
# 57         1         0
# 58         5        34
# 59         7         7

# %%
dfa_normal = pd.DataFrame()

for i, row in df_normal2.iterrows():
    data_type = row.data_type
    sample_type = row.sample_type
    file_id = row.file_id
    
    dft = get_table_searching_for_fileID(pid=pid, data_type=data_type, sample_type=sample_type, file_id=file_id, verbose=False)

    if dft.empty:
        print(f"No data found for file_id: {i} {file_id} {data_type} and {sample_type}")
        continue

    dft = dft[cols]
    dft = dft.rename(columns={"counts": f"counts_{i+1}"})

    if dfa_normal.empty:
        dfa_normal = dft
    else:
        dfa_normal = dfa_normal.merge(dft, on=common_cols, how="outer") 

print(len(dfa_normal))
dfa_normal.head(3)
# Out:
# 60660
#            gene_id  symbol       gene_type  counts_1
# 0  ENSG00000000003  TSPAN6  protein_coding      1511
# 1  ENSG00000000005    TNMD  protein_coding       167
# 2  ENSG00000000419    DPM1  protein_coding       948

# %%
fname = '%s_for_%s_case_%s_' % (file_type, pid, case_id)
fname = title_replace(fname)
