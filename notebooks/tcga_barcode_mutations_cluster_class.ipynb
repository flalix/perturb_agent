# %%
# !python --version
# Out:
# Python 3.11.14

# %%
import os, sys
import pandas as pd

from pathlib import Path

ROOT = Path().resolve().parent
SRC = os.path.join(ROOT, "src")

if str(SRC) not in sys.path:
    sys.path.append(str(SRC))

print("ROOT:", ROOT)
print("SRC added:", SRC)

from libs.calc_degs_lib import CALC_DEGS
from libs.tcga_gdc_lib import *
from libs.Basic import *
# Out:
# ROOT: /home/flavio/uv/perturb_agent
# SRC added: /home/flavio/uv/perturb_agent/src

# %% [markdown]
# ### Defaults

# %%
ROOT = Path().resolve().parent
root0 = ROOT / "data"

gdc = GDC(root0=root0)

os.listdir(root0)[:10]
# Out:
# ['cancer', 'reactome', 'vector_store', 'TCGA', 'gdc_programs.txt']

# %% [markdown]
# ### Get all programs

# %%
force=False
verbose=True

prog_list = gdc.get_gdc_progams(force=force, verbose=verbose)
# Out:
# File read at '/home/flavio/uv/perturb_agent/data/gdc_programs.txt'

# %%
np.array(prog_list)
# Out:
# array(['TCGA', 'MATCH', 'TARGET', 'CGCI', 'CMI', 'APOLLO', 'BEATAML1.0',
#        'CPTAC', 'MP2PRT', 'ALCHEMIST', 'CCDI', 'CCG', 'CDDP_EAGLE',
#        'CTSP', 'EXCEPTIONAL_RESPONDERS', 'FM', 'HCMI', 'MMRF', 'NCICCR',
#        'OHSU', 'ORGANOID', 'RC', 'REBC', 'TRIO', 'VAREPOP', 'WCDT'],
#       dtype='<U22')

# %% [markdown]
# ### Primary sites given a program

# %%
gdc.url_gdc_project
# Out:
# 'https://api.gdc.cancer.gov/projects'

# %%
force=False
verbose=False

prog_id = 'TCGA'

gdc.set_program(prog_id)
df_psi = gdc.get_primary_sites(prog_id=prog_id, force=False, verbose=verbose)

i=0
primary_site = df_psi.iloc[i].primary_site
gdc.set_primary_site(primary_site=primary_site)
# Out:
# True

# %%
verbose=False

i=5
primary_site = df_psi.iloc[i].primary_site
print(">>", primary_site, end=" ")

dfw, dfh, dfstat = gdc.entropy_analysis_for_primary_site(primary_site=primary_site, Kmin=2, Kmax=12,
                                                         min_barcodes=2, verbose=verbose)

print(len(dfw))

print("\n----------- end ------------")
# Out:
# >> Breast >>> k 2 - [0 1] - cluster 0 0 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 7
#       4 primary_site = df_psi.iloc[i].primary_site
#       5 print(">>", primary_site, end=" ")
# ----> 7 dfw, dfh, dfstat = gdc.entropy_analysis_for_primary_site(primary_site=primary_site, Kmin=2, Kmax=12,
#       8                                                          min_barcodes=2, verbose=verbose)
#      10 print(len(dfw))
#      12 print("\n----------- end ------------")
#
# File ~/uv/perturb_agent/src/libs/tcga_gdc_lib.py:2267, in GDC.entropy_analysis_for_primary_site(self, primary_site, Kmin, Kmax, min_barcodes, verbose)
#    2265 for cluster in range(min_cluster, max_cluster + 1):
#    2266 	print(f">>> k {k} - {unique_labels} - cluster {cluster}", min_cluster, max_cluster)
# -> 2267 	dfc = self.cluster_mutation_table(
#    2268 		dfpiv=dfpiv,
#    2269 		labels=labels,
#    2270 		cluster=cluster,
#    2271 		min_barcodes=min_barcodes
#    2272 	)
#    2274 	n_cluster = dfc.shape[0]
#    2275 	gene_degree = dfc.sum(axis=0).sort_values(ascending=False)
#
# File ~/uv/perturb_agent/src/libs/tcga_gdc_lib.py:2167, in GDC.cluster_mutation_table(self, dfpiv, labels, cluster, min_barcodes)
#    2164 	def cluster_mutation_table(self, dfpiv:pd.DataFrame, labels, cluster:int=1,
#    2165                            min_barcodes:int=2) -> pd.DataFrame:
# -> 2167 		labels = pd.Series(labels, index=dfpiv.index)
#    2168 		sel_barcodes = labels[labels == cluster].index
#    2169 		dff = dfpiv.loc[sel_barcodes]
#
# File ~/uv/perturb_agent/.venv/lib/python3.11/site-packages/pandas/core/series.py:578, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     576     index = default_index(len(data))
#     577 elif is_list_like(data):
# --> 578     com.require_length_match(data, index)
#     580 # create/copy the manager
#     581 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File ~/uv/perturb_agent/.venv/lib/python3.11/site-packages/pandas/core/common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (62) does not match length of index (63)

# %%
dfw

# %%
gdc.dfpiv.shape

# %%
gdc.dfpiv
